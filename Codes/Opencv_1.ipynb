# %%
import cv2

# %%
image = cv2.imread('image_1.jpg')

# %%
# for python 3
# print(image)

# for python 2
# print image

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)
plt.show()

# %%
while True:
    cv2.imshow('img',image)
    cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-3ab12a4a5ee0> in <module>()
#       1 while True:
#       2     cv2.imshow('img',image)
# ----> 3     cv2.waitKey(1)
#
# KeyboardInterrupt:
